# %%
# importing pandas as pd 
import pandas as pd 
  
class_4 = open("classes/class_4/1.txt", "r")
content_4 = class_4.read()
print(content_4)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645
# Email -: info@apsranikhet.in, Tel No. -: 05966221271
#
# oy
#
#
#
#
#
# S
#
#
#
# SL netors)
# GN
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# NAME : PRIYANSI BISHT COURSE : GENERAL - CLASS : IV SEC : A -ROLLNo:20 ADM. NO. : 7271
# FATHER'S NAME : ANAND SINGH BISHT MOTHER'S NAME : REKHA BISHT D. O. B. : 14-04-2010 PHONE NO. 9756820155
# ADDRESS : VILL-KHANIYA, PO-PANTKOTLI, RANIKHET, DISTT-ALMORA
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SCHOLASTIC AREAS
# TERM 1 TERM 2
# SUBJECT SUBJECT
# SUBJECTS PERIODIC . 7 Marks PERIODIC . 7 Marks
# TEST-1 re ra 1 ee er a Obtained Grade TEST.2 aay eee 2 Se en eet Obtained Grade
# (10) (5) (100) (10) (5) (100)
# ENGLISH 9.0 4.0 4.0 69.0 86.0 A2 8.6 5.0 5.0 64.0 82.6 A2
# ...

# %% [markdown]
# # class 5

# %%
class_5 = open("classes/class_5/1.txt", "r")
content_5 = class_5.read()
print(content_5)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645
# Email -: info@apsranikhet.in, Tel No. -: 05966221271
#
#
#
#
# oy
#
#
#
# S
#
#
#
#
#
# SL netors)
# GN
#
#
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# NAME : PRIYANSU BHAKUNI
# FATHERâ€™S NAME : NARENDRA SINGH
# ADDRESS : NEAR SBI, CHILIYANAULA, RANIKHET
#
# COURSE : GENERAL - CLASS : V
# MOTHER'S NAME : HEMLATA BHAKUNI
#
# SEC : C -ROLLNo:19
# D. O. B. : 16-12-2009
#
# ADM. NO. : 7082
# PHONE NO. 8755946725
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SCHOLASTIC AREAS
# TERM 1 TERM 2
# SUBJECT SUBJECT
# SUBJECTS PERIODIC . 7 Marks PERIODIC â€˜ 7 Marks
# TEST-1 PORT FOLIO 1 EReRDIeba HALF {EARLY Obtained Grade TEST.2 PORT FOLIO 2 See ANNUAL EXAM Obtained Grade
# (10) (5) (100) (10) (5) (100)
# ...

# %% [markdown]
# # class 6

# %%
class_6 = open("classes/class_6/1.txt", "r")
content_6 = class_6.read()
print(content_6)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645
# Email -: info@apsranikhet.in, Tel No. -: 05966221271
#
#
#
#
#
#
#
# oy
#
#
#
#
#
# S
#
# SL netors)
# GN
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# NAME : MAHIR PANT
#
# ADDRESS : Badriview, Ranikhet
#
# FATHER'S NAME : HARISH CHANDRA PANT
#
# COURSE : GENERAL - CLASS: VI
# MOTHER'S NAME : USHA PANT
#
# SEC : C -ROLLNo:19
# D. O. B. : 28-12-2008
#
# ADM. NO. : 8417
# PHONE NO. 8954316822
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SCHOLASTIC AREAS
# TERM 1 TERM 2
# SUBJECT SUBJECT
# SUBJECTS PERIODIC . 7 Marks PERIODIC ' 7 Marks
# TEST-1 ao eae 1 Se er a Obtained Grade TEST.2 ao A 2 Soa E ae eel Obtained Grade
# (10) (5) (100) (10) (5) (100)
# ENGLISH 8.0 5.0 5.0 63.0 81.0 A2 8.8 4.0 5.0 70.0 87.8 A2
# ...

# %% [markdown]
# #  class 7

# %%
class_7 = open("classes/class_7/1.txt", "r")
content_7 = class_7.read()
print(content_7)
# Out:
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645
# Email -: info@apsranikhet.in, Tel No. -: 05966221271
#
# oy
#
#
#
# S
#
#
#
# SL netors)
# GN
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# SEC : A -ROLLNo:4
# D. O. B. : 24-02-2007
#
# ADM. NO. : 7731
# PHONE NO. 9411794174
#
# COURSE : GENERAL - CLASS : VII
# MOTHER'S NAME : MAYA DEVI
#
# NAME : ANURAG BISHT
# FATHER'S NAME : PRAKASH SINGH
# ADDRESS : VILL-DHAMOLI, PO-NAULAKOT, DISTT-ALMORA, PIN-263621
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SCHOLASTIC AREAS
# TERM 1 TERM 2
# SUBJECT SUBJECT
# SUBJECTS PERIODIC . 7 Marks PERIODIC ' 7 Marks
# TEST-1 ao eae 1 Se er a Obtained Grade TEST.2 ao A 2 Soa E ae eel Obtained Grade
# (10) (5) (100) (10) (5) (100)
# ENGLISH 7.2 4.0 3.0 49.0 63.2 B2 7.2 3.0 3.0 53.0 66.2 B2
# ...

# %% [markdown]
# # class 8

# %%
class_8 = open("classes/class_8/1.txt", "r")
content_8 = class_8.read()
print(content_8)
# Out:
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645
# Email -: info@apsranikhet.in, Tel No. -: 05966221271
#
#
#
#
#
# oy
#
#
#
# S
#
# SL netors)
# GN
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# NAME : NIDHI NEGI
# FATHER'S NAME : SATISH SINGH
# ADDRESS : VILL-TONAJI, PO-SALNA, TEH-POKHARI, DISTT-CHAMOLI UK
#
# COURSE : GENERAL - CLASS : VIII
# MOTHER'S NAME : REENA NEGI
#
# SEC : D -ROLLNo:8
# D. O. B. : 07-03-2007
#
# ADM. NO. : 8129
# PHONE NO. 9458160564
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SCHOLASTIC AREAS
# TERM 1 TERM 2
# SUBJECT SUBJECT
# SUBJECTS PERIODIC . 7 Marks PERIODIC ' 7 Marks
# TEST-1 ao eae 1 Se er a Obtained Grade TEST.2 ao A 2 Soa E ae eel Obtained Grade
# (10) (5) (100) (10) (5) (100)
# ENGLISH 4.8 5.0 5.0 67.0 81.8 A2 8.0 5.0 5.0 70.0 88.0 A2
# ...

# %% [markdown]
# # class 9

# %%
class_9 = open("classes/class_9/1.txt", "r")
content_9 = class_9.read()
print(content_9)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET Ses
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645
# Email -: info@apsranikhet.in, Tel No. -: 05966221271
#
#
#
# 1
#
# TRUTH IS GOD
# vad ae
#
#
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# NAME : CHANCHAL SINGH D. O. B. : 09-01-2006 ADM. NO. : 7495
# FATHER'S NAME : HOSHIYAR SINGH CLASS - SECTION : IX - D ROLL NO. :5
# MOTHER'S NAME : PUSHPA DEVI PHONE NO. : 7599193021
#
# ADDRESS : VILL PO-PANKHU, TEH-DIDIHAT, DISTT-PITHORAGARH, UK
#
#
#
#
#
# PART 1 : ACADEMIC PERFORMANCE - SCHOLASTIC AREAS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ANNUAL REPORT CARD
# SUBJECTS PERIODIC SUBJECT 7
# TEST-1 PORT FOLIO-1 ENRICHMENT-1 ANNUAL EXAM | Marks Obtained Grade
# (5) (80) (100 )
# (10) (5)
# ENGLISH 8.2 4.0 3.5 66.0 81.7 A2
# HINDI 7.0 4.5 3.5 57.0 72.0 Bi
# MATHEMATICS 7.6 4.5 4.0 57.0 73.1 Bi
# ...

# %% [markdown]
# # class 11

# %%
class_11 = open("classes/class_11/1.txt", "r")
content_11 = class_11.read()
print(content_11)
# Out:
#
#
#
#
#
#
#
#
#
#
# ARMY PUBLIC SCHOOL RANIKHET
#
# Near Ranikhet Club Ranikhet, Distt. Almora Uttarakhand - 263645,Email -: info@apsranikhet.in, Tel No. -
# 05966221271
#
# Stig
# me
# LfÂ»
#
# UL Neto)
# GY =e
#
#
#
#
#
# REPORT CARD - SESSION ( 2019-2020 )
#
#
#
#
#
# NAME : PRIYANKA COURSE - CLASS : COMMERCE - XI SEC-ROLLNO: C - 12 ADM. NO. : 7035
# FATHERâ€™S NAME : GOVIND RAM MOTHER'S NAME : GANGA DEVI D. O. B. : 26-08-2002 ATTENDANCE : 202/216
# ADDRESS : QTR NO.-T-4/9 HALF MOON LINE, RANIKHET
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SCHOLASTIC AREAS
# Unit Test-1 HALF YEARLY Unit Test-2 ANNUAL
# = = = = TH OBT PR OBT | cranp
# SUBJECT % by Â© B B % BD 8 Be B Â© B ba Be fF 8 | TOTAL | TOTAL | TOTAL | TOTAL TOTAL
# = Â°o ~ = Â°o = 3 ~ = Â°o ~ = Â°o = 3 ~
# = = o = z = bs o = = Go = z = bs o WTG WTG WTG WTG
# F F = F F a a = F F E F F o a =
# ...

# %% [markdown]
# # Result of class 11 don't match with other classes so we will only use class 4-9 result for building our model.

# %%
x = content.find("HINDI")
eng_len = len('HINDI')


index_1_eng = x+eng_len
index_2_eng = x+eng_len+4
eng_periodic = content[index_1_eng:index_2_eng]
print(eng_periodic)

# %%
print(eng_len)
# Out:
# 5
